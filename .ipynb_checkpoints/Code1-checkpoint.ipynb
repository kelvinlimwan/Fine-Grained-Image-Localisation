# %%
### PACKAGES
import csv
import numpy as np
import cv2
import os
import matplotlib
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import pickle
from copy import deepcopy
from asift import *
#import keras
from tensorflow import keras #for kelvin's machine
from find_obj import init_feature, filter_matches, explore_match
from scipy import ndimage

# %%
### CONSTANTS
ROOTPATH = './'
IMG_HEIGHT = 490
IMG_WIDTH = 680
NUM_CHANNELS = 3

# %%
train_img_names = [] # list of train image names as strings
train_img_labels = [] # list of train images labels as tuples (latitude, longitude)
with open('COMP90086_2021_Project_train/train.csv') as train_csv:
    reader = csv.reader(train_csv, delimiter=',')
    next(reader) # skip header row
    for row in reader:
        name = row[0] # string
        label = (float(row[1]), float(row[2])) # tuple
        train_img_names.append(name)
        train_img_labels.append(label)
'''
# train images stored as numpy array
resize = 0.5
IMG_HEIGHT = int(IMG_HEIGHT * resize)
IMG_WIDTH = int(IMG_WIDTH * resize)
train_size = (len(train_img_names), IMG_HEIGHT, IMG_WIDTH,NUM_CHANNELS )
#print(train_images.shape)


train_images = np.zeros(train_size, dtype='uint8')
for i in range(len(train_img_names)):
    name = train_img_names[i]
    subpath = 'COMP90086_2021_Project_train/train/' + name + '.jpg'
    img = cv2.imread(os.path.join(ROOTPATH, subpath))
    img = cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
#     print(img.shape)
    train_images[i] = img

# train labels stored as numpy array
train_labels = np.array(train_img_labels)
print(train_labels[0])
print(train_images.shape)
'''
# Out:
# "\n# train images stored as numpy array\nresize = 0.5\nIMG_HEIGHT = int(IMG_HEIGHT * resize)\nIMG_WIDTH = int(IMG_WIDTH * resize)\ntrain_size = (len(train_img_names), IMG_HEIGHT, IMG_WIDTH,NUM_CHANNELS )\n#print(train_images.shape)\n\n\ntrain_images = np.zeros(train_size, dtype='uint8')\nfor i in range(len(train_img_names)):\n    name = train_img_names[i]\n    subpath = 'COMP90086_2021_Project_train/train/' + name + '.jpg'\n    img = cv2.imread(os.path.join(ROOTPATH, subpath))\n    img = cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))\n#     print(img.shape)\n    train_images[i] = img\n\n# train labels stored as numpy array\ntrain_labels = np.array(train_img_labels)\nprint(train_labels[0])\nprint(train_images.shape)\n"

# %%
test_img_names = [] # list of test image names as strings
with open('COMP90086_2021_Project_test/imagenames.csv') as test_csv:
    reader = csv.reader(test_csv, delimiter=',')
    next(reader) # skip header row
    for row in reader:
        name = row[0] # string
        test_img_names.append(name)
'''
# test images stored as numpy array
test_size = (len(test_img_names), IMG_HEIGHT, IMG_WIDTH, NUM_CHANNELS)
test_images = np.zeros(test_size, dtype='uint8')
for i in range(len(test_img_names)):
    name = test_img_names[i]
    subpath = 'COMP90086_2021_Project_test/test/' + name + '.jpg'
    img = cv2.imread(os.path.join(ROOTPATH, subpath))
    img = cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))

    
    test_images[i] = img
    
# train_images = train_images.reshape(train_images.shape[0], 32, 32, 3).astype('float32')
# test_images = test_images.reshape(test_images.shape[0], 32, 32, 3).astype('float32')
'''
# Out:
# "\n# test images stored as numpy array\ntest_size = (len(test_img_names), IMG_HEIGHT, IMG_WIDTH, NUM_CHANNELS)\ntest_images = np.zeros(test_size, dtype='uint8')\nfor i in range(len(test_img_names)):\n    name = test_img_names[i]\n    subpath = 'COMP90086_2021_Project_test/test/' + name + '.jpg'\n    img = cv2.imread(os.path.join(ROOTPATH, subpath))\n    img = cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))\n\n    \n    test_images[i] = img\n    \n# train_images = train_images.reshape(train_images.shape[0], 32, 32, 3).astype('float32')\n# test_images = test_images.reshape(test_images.shape[0], 32, 32, 3).astype('float32')\n"

# %%
##CHECK
train_img_1 = cv2.cvtColor(train_images[0], cv2.COLOR_BGR2RGB)
train_img_n = cv2.cvtColor(train_images[-1], cv2.COLOR_BGR2RGB)
test_img_1 = cv2.cvtColor(test_images[0], cv2.COLOR_BGR2RGB)
print(train_img_1.shape)
test_img_n = cv2.cvtColor(test_images[-1], cv2.COLOR_BGR2RGB)

plt.subplot(2,2,1)
plt.imshow(train_img_1) 
plt.title('train image 1')
plt.axis('off')
plt.subplot(2,2,2)
plt.imshow(train_img_n) 
plt.title('train image n')
plt.axis('off')
plt.subplot(2,2,3)
plt.imshow(test_img_1) 
plt.title('test image 1')
plt.axis('off')
plt.subplot(2,2,4)
plt.imshow(test_img_n) 
plt.title('test image n')
plt.axis('off')
plt.show()

# %%
# FIRST ATTEMPT: BASELINE 
model = keras.models.Sequential()

model.add(layers.Input((IMG_HEIGHT, IMG_WIDTH, NUM_CHANNELS)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.Conv2D(16, (3, 3), activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(2))


#op = keras.optimizers.adam_v2.Adam()
op = keras.optimizers.Adam() # for kelvin's machine
model.compile(loss='mae', optimizer=op)
print(train_images.shape)
model.summary()

h = model.fit(train_images, train_labels,verbose = 1,batch_size=1,validation_split = 0.1,epochs = 20)

# %%
import sys
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                         key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))

# %% [markdown]
# ### SIFT + FLANN

# %%
### SIFT + FLANN

k_nn = 2
lowe_ratio = 0.7
num_closest_matches = 5

# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks=50)   # or pass empty dictionary

# If there exists a checkpoint, use saved weights and indices
if os.path.exists('./checkpoint/weights.pickle') and os.path.exists('./checkpoint/indices.pickle'):
    with open(os.path.join("checkpoint","weights.pickle"),'rb') as handle:
        weights = pickle.load(handle)
    with open(os.path.join(os.getcwd(),"checkpoint","indices.pickle"),'rb') as handle:
        indices = pickle.load(handle)
        
    # Skip already completed test images
    test_images_sift = test_images[len(weights):]
    print("Found checkpoint, skipping to test image",len(weights))
else:
    test_images_sift = deepcopy(test_images)
    weights = []
    indices = []
    

sift = cv2.SIFT_create() # initialise SIFT detector

for i in range(len(test_images_sift)):    
    print(i)

    test_image = test_images_sift[i]
    # convert test image to grayscale
    gray_test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    
    # SIFT keypoints and descriptors for test image
    keypoints_test, descriptors_test = sift.detectAndCompute(gray_test_image, None)
        
    # initialise FLANN
    flann = cv2.FlannBasedMatcher(index_params,search_params)
    
    # stores 5 highest number of keypoint matches
    best_num_matches = np.zeros(num_closest_matches, dtype='uint64')
    
    matches_index = np.zeros(num_closest_matches,dtype='uint64')
    # stores 5 train images with highest number of keypoint matches
    #best_image_matches = np.zeros((num_closest_matches, IMG_HEIGHT, IMG_WIDTH, NUM_CHANNELS), dtype='uint8')
    # stores  corresponding matching images 
    #circles_and_lines = np.zeros((num_closest_matches, IMG_HEIGHT, IMG_WIDTH*2, NUM_CHANNELS), dtype='uint8')

    for j in range(len(train_images)):
        train_image = train_images[j]
        # convert train image to grayscale
        gray_train_image = cv2.cvtColor(train_image,cv2.COLOR_BGR2GRAY)
        
        # SIFT keypoints and descriptors for train image
        keypoints_train, descriptors_train = sift.detectAndCompute(gray_train_image, None)
        
        
        
        # when there is no descriptor less than k_nn descriptors
        if descriptors_test is None or descriptors_train is None or \
        descriptors_test.shape[0] < k_nn or descriptors_train.shape[0] < k_nn:
            continue
            
        # Draws a circle with the size of each keypoint and show its orientation
        keypoints_test_with_size = cv2.drawKeypoints(gray_test_image, keypoints_test, None,
                                                     flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
        keypoints_train_with_size = cv2.drawKeypoints(gray_train_image, keypoints_train, None,
                                                      flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
        
        # Matching descriptors using KNN algorithm
        matches = flann.knnMatch(descriptors_test, descriptors_train, k=k_nn)
        
        # Create a mask to draw all good matches
        matchesMask = []
        # Store all good matches as per Lowe's Ratio test.
        good = []
        for m,n in matches:
            if m.distance < lowe_ratio *n.distance:
                good.append(m)
                matchesMask.append([1,0]) # Match
            else:
                matchesMask.append([0,0]) # Mismatch
        num_matches = len(good)
        
        # Draw all good matches
        draw_params = dict(#matchColor = (0,255,0),  #If you want a specific colour
                           #singlePointColor = (255,0,0), #If you want a specific colour
                            matchesMask = matchesMask,
                            flags = cv2.DrawMatchesFlags_DEFAULT)

        good_matches = cv2.drawMatchesKnn(gray_test_image, keypoints_test, gray_train_image,
                                          keypoints_train, matches, None, **draw_params)
        
        # compares to closest matches and update as necessary
        for k in range(num_closest_matches):
            if num_matches >= best_num_matches[k]:
                best_num_matches = np.insert(best_num_matches, k, num_matches, 0)
                best_num_matches = np.delete(best_num_matches, -1, 0)
                matches_index = np.insert(matches_index, k, j, 0)
                matches_index = np.delete(matches_index, -1, 0)
                #best_image_matches = np.insert(best_image_matches, k, train_image, 0)
                #best_image_matches = np.delete(best_image_matches, -1, 0)
                #circles_and_lines = np.insert(circles_and_lines, k, good_matches, 0)
                #circles_and_lines = np.delete(circles_and_lines, -1, 0)
                break
    
    '''
    # display 5 closest images
    for z in range(num_closest_matches):
        plt.subplots(figsize=(10, 10)) 
        plt.subplot(1, 2, 1)
        plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB), cmap='gray')  
        plt.title('Test Image')
        plt.axis('off')
        plt.subplot(1, 2, 2)
        plt.imshow(cv2.cvtColor(best_image_matches[z], cv2.COLOR_BGR2RGB), cmap='gray')  
        plt.title('Train Image')
        plt.axis('off')
        plt.show()
        
        plt.figure(figsize=(15, 15))
        plt.imshow(circles_and_lines[z])
        plt.title(f'Number of good matches between two images: {best_num_matches[z]}')
        plt.axis('off')
        plt.show()
    '''
    weights.append(list(best_num_matches))
    indices.append(list(matches_index))
    
    if i % 5 == 0: # Save weights and Indices every 5 test images 
        with open(os.path.join("checkpoint","weights.pickle"),'wb') as handle:
            pickle.dump(weights, handle, protocol=pickle.HIGHEST_PROTOCOL)
            
        with open(os.path.join(os.getcwd(),"checkpoint","indices.pickle"),'wb') as handle:
            pickle.dump(indices, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
### SIFT + FLANN

predictions_top1 = []
predictions_avg = []
predictions_weighted_avg = []
for i in range(len(indices)):
    weight = weights[i]
    test_img_indices = indices[i]
    
    ### PREDICTIONS_TOP_1
    predictions_top1.append(train_img_labels[test_img_indices[0]])
    
    ### PREDICTIONS_AVG
    pred_avg_x = 0
    pred_avg_y = 0
    for ind in test_img_indices:
        x_lab, y_lab= train_img_labels[ind]
        pred_avg_x += x_lab
        pred_avg_y += y_lab
    pred_avg_x /= len(test_img_indices)
    pred_avg_y /= len(test_img_indices)
    
    predictions_avg.append((pred_avg_x, pred_avg_y))
    
    ### PREDICTIONS_WEIGHTED_AVG
    pred_weighted_avg_x = 0
    pred_weighted_avg_y =0
    for j in range(len(test_img_indices)):
        x_lab, y_lab= train_img_labels[test_img_indices[j]]
        w = weight[j] / sum(weight)
        pred_weighted_avg_x += x_lab * w
        pred_weighted_avg_y += y_lab * w
    
    predictions_weighted_avg.append((pred_weighted_avg_x, pred_weighted_avg_y))

# %%
### SIFT + FLANN

header = ['id', 'x', 'y']
with open(ROOTPATH + 'predictions_top1.csv', 'w', newline='') as top1:
    writer = csv.writer(top1)
    writer.writerow(header)
    for i in range(len(test_img_names)):
        img_name = test_img_names[i]
        x_val, y_val = predictions_top1[i]
        data = [img_name, str(x_val), str(y_val)]
        writer.writerow(data)
    top1.close()
    
with open(ROOTPATH + 'predictions_avg.csv', 'w', newline='') as avg:
    writer = csv.writer(avg)
    writer.writerow(header)
    for i in range(len(test_img_names)):
        img_name = test_img_names[i]
        x_val, y_val = predictions_avg[i]
        data = [img_name, str(x_val), str(y_val)]
        writer.writerow(data)
    avg.close()
    
with open(ROOTPATH + 'predictions_weighted_avg.csv', 'w', newline='') as weighted_avg:
    writer = csv.writer(weighted_avg)
    writer.writerow(header)
    for i in range(len(test_img_names)):
        img_name = test_img_names[i]
        x_val, y_val = predictions_weighted_avg[i]
        data = [img_name, str(x_val), str(y_val)]
        writer.writerow(data)
    weighted_avg.close()

# %% [markdown]
# ### SIFT FEATURE EXTRACTION, THEN CNN

# %%
train_images_descriptors = np.zeros((len(train_images),200,128))
print(train_images_descriptors.shape)
rows_to_delete = []
descriptors_labels = deepcopy(train_labels)
for i in range(len(train_images)):    

    image = train_images[i]
    
    # convert test image to grayscale
    gray_train_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    sift = cv2.SIFT_create(200) # initialise SIFT detector
    
    # SIFT keypoints and descriptors for test image
    keypoints_train, descriptors_train = sift.detectAndCompute(gray_train_image, None)
    if descriptors_train is None:
        rows_to_delete.append(i)
        continue
    if descriptors_train.shape[0] < 200:
        times_to_pad =200-descriptors_train.shape[0]
        pad = np.zeros((times_to_pad,128))
        descriptors_train = np.r_[descriptors_train, pad]
    elif descriptors_train.shape[0] > 200:
        descriptors_train = descriptors_train[:200]
    train_images_descriptors[i] = descriptors_train
#     print(descriptors_train.shape)

print(descriptors_labels.shape)
 
if len(rows_to_delete) != 0:
    rows_to_delete.reverse()
    for ind in rows_to_delete:
        train_images_descriptors = np.delete(train_images_descriptors,ind,0)

        descriptors_labels =  np.delete(descriptors_labels,ind,0)
        
        
print(train_images_descriptors.shape)
print(descriptors_labels.shape)

# %%
# Attempt: CNN Using SIFT Descriptors as Features
train_images_descriptors_1 = np.expand_dims(train_images_descriptors, axis=-1)
train_images_descriptors_1 = train_images_descriptors_1/255 # normalise

model = keras.models.Sequential()
model.add(layers.Input((200,128,1)))

# model.add(layers.Conv2D(16, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2,2)))
# model.add(layers.Conv2D(8, (3, 3), activation='relu'))
# model.add(layers.MaxPooling2D((2,2)))
#model.add(layers.Flatten())
model.add(layers.Dense(200, activation='relu'))
model.add(layers.Dense(2))#, activation='softmax'))

op = keras.optimizers.Adam() # for kelvin's machine
model.compile(loss='mae', optimizer=op)
h = model.fit(train_images_descriptors_1, descriptors_labels,verbose = 1,batch_size=50,validation_split = 0.1,epochs = 10)

# %% [markdown]
# ### ASIFT + FLANN

# %%
### TESTING ASIFT

train_images1 = cv2.cvtColor(train_images[31], cv2.COLOR_BGR2GRAY)

detector, matcher = init_feature("sift-flann")

pool=ThreadPool(processes = cv.getNumberOfCPUs())

for j in range(len(train_images)):
    train_image = train_images[j]
    train_images2 = cv2.cvtColor(train_image, cv.COLOR_BGR2GRAY)

    kp1, desc1 = affine_detect(detector, train_images1, pool=pool)
    kp2, desc2 = affine_detect(detector, train_images2, pool=pool)

    if len(desc1) < 2 or len(desc2) < 2:
        continue
    raw_matches = matcher.knnMatch(desc1, trainDescriptors = desc2, k = 2) #2

    p1, p2, kp_pairs = filter_matches(kp1, kp2, raw_matches)
    H, status = cv2.findHomography(p1, p2, cv2.RANSAC, 5.0)
    print('%d / %d  inliers/matched' % (np.sum(status), len(status)))

# %%
### ASIFT + FLANN

k_nn = 2
lowe_ratio = 0.7
num_closest_matches = 5

# Initialize asift with flann (Note: remove -flann to use bruteforce)
detector, matcher = init_feature("sift-flann")
pool=ThreadPool(processes = cv.getNumberOfCPUs())

# If there exists a checkpoint, use saved weights and indices
'''
if os.path.exists('./checkpoint/asift_weights.pickle') and os.path.exists('./checkpoint/asift_indices.pickle'):
    with open(os.path.join("checkpoint","asift_weights.pickle"),'rb') as handle:
        weights = pickle.load(handle)
    with open(os.path.join(os.getcwd(),"checkpoint","asift_indices.pickle"),'rb') as handle:
        indices = pickle.load(handle)
        
    # Skip already completed test images
    test_images_asift=test_images[len(weights):]
    print("Found checkpoint, skipping to test image",len(weights))
else:
    test_images_asift=deepcopy(test_images)
    weights = []
    indices = []
'''
test_images_asift=deepcopy(test_images)
weights=[]
indices=[]
for i in range(1):#range(len(test_images_asift)):    
    #print(i)
    test_image = test_images_asift[i]
    # convert test image to grayscale
    gray_test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    kp1, desc1 = affine_detect(detector, gray_test_image, pool=pool)

    
    # stores 5 highest number of keypoint matches
    best_matches = np.zeros(num_closest_matches, dtype='uint64')
    
    matches_index = np.zeros(num_closest_matches,dtype='uint64')
    # stores 5 train images with highest number of keypoint matches
    best_image_matches = np.zeros((num_closest_matches, IMG_HEIGHT, IMG_WIDTH, NUM_CHANNELS), dtype='uint8')
    # stores  corresponding matching images 
    #circles_and_lines = np.zeros((num_closest_matches, IMG_HEIGHT, IMG_WIDTH*2, NUM_CHANNELS), dtype='uint8')

    for j in range(len(train_images)):
        print(j)
        train_image = train_images[j]
        # convert train image to grayscale
        gray_train_image = cv2.cvtColor(train_image,cv2.COLOR_BGR2GRAY)
        
        kp2, desc2 = affine_detect(detector, gray_train_image, pool=pool)
        
        if len(desc1) < k_nn or len(desc2) < k_nn:
            continue
        #matches = flann.knnMatch(descriptors_test, descriptors_train, k=k_nn)
        raw_matches = matcher.knnMatch(desc1, trainDescriptors = desc2, k = k_nn) #2
        
        p1, p2, kp_pairs = filter_matches(kp1, kp2, raw_matches)
        
        if p1.shape[0] < 4 or p2.shape[0] < 4:
            continue
            
        H, status = cv2.findHomography(p1, p2, cv2.RANSAC, 5.0)
        # Where H is the resulting single-strain matrix.
        # status returns a list of feature points that represent successful matches.
        # ptsA, ptsB are keypoints.
        # The three parameters cv2.RANSAC, ransacReprojThreshold, maxIters are related to RANSAC.
        # ransacReprojThreshold: Maximum reprojection error in the RANSAC algorithm to consider a point as an inlier. 
        # maxIters: The maximum number of RANSAC-based robust method iterations.
        #print('%d / %d  inliers/matched' % (np.sum(status), len(status)))
        
        num_good_matches = np.sum(status)
        
        # compares to closest matches and update as necessary
        for k in range(num_closest_matches):
            if num_good_matches >= best_matches[k]:
                best_matches = np.insert(best_matches, k, num_good_matches, 0)
                best_matches = np.delete(best_matches, -1, 0)
                matches_index = np.insert(matches_index, k, j, 0)
                matches_index = np.delete(matches_index, -1, 0)
                best_image_matches = np.insert(best_image_matches, k, train_image, 0)
                best_image_matches = np.delete(best_image_matches, -1, 0)
                #circles_and_lines = np.insert(circles_and_lines, k, good_matches, 0)
                #circles_and_lines = np.delete(circles_and_lines, -1, 0)
                break
    
    
    # display 5 closest images
    for z in range(num_closest_matches):
        plt.subplots(figsize=(10, 10)) 
        plt.subplot(1, 2, 1)
        plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB), cmap='gray')  
        plt.title('Test Image')
        plt.axis('off')
        plt.subplot(1, 2, 2)
        plt.imshow(cv2.cvtColor(best_image_matches[z], cv2.COLOR_BGR2RGB), cmap='gray')  
        plt.title('Train Image')
        plt.axis('off')
        plt.show()
        print("NUMBER OF GOOD MATCHES: ", best_matches[z])
        
        #plt.figure(figsize=(15, 15))
        #plt.imshow(circles_and_lines[z])
        #plt.title(f'Number of good matches between two images: {best_num_matches[z]}')
        #plt.axis('off')
        #plt.show()
    
    weights.append(list(best_matches))
    indices.append(list(matches_index))
    
    if i % 5 == 0: # Save weights and Indices every 5 test images 
        with open(os.path.join("checkpoint","asift_weights.pickle"),'wb') as handle:
            pickle.dump(weights, handle, protocol=pickle.HIGHEST_PROTOCOL)
            
        with open(os.path.join(os.getcwd(),"checkpoint","asift_indices.pickle"),'wb') as handle:
            pickle.dump(indices, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### SELF-SUPERVISED LEARNING

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model

# train images stored as numpy array
train_size = (len(train_img_names), 128, 128 ,NUM_CHANNELS )
train_images_ss = np.zeros(train_size, dtype='uint8')
for i in range(len(train_img_names)):
    name = train_img_names[i]
    subpath = 'COMP90086_2021_Project_train/train/' + name + '.jpg'
    img = image.load_img(subpath, target_size=(128,128))
    img = image.img_to_array(img)
    #img = preprocess_input(img)
    train_images_ss[i] = img
train_images_ss = train_images_ss.astype(float)/255.
# train labels stored as numpy array
train_labels_ss = np.array(train_img_labels)


# test images stored as numpy array
test_size = (len(test_img_names), 128, 128, NUM_CHANNELS)
test_images_ss = np.zeros(test_size, dtype='uint8')
for i in range(len(test_img_names)):
    name = test_img_names[i]
    subpath = 'COMP90086_2021_Project_test/test/' + name + '.jpg'
    img = image.load_img(subpath, target_size=(128,128))
    img = image.img_to_array(img)
    #img = preprocess_input(img)    
    test_images_ss[i] = img
test_images_ss = test_images_ss.astype(float)/255.

print(train_images_ss.shape)
print(train_labels_ss.shape)
print(test_images_ss.shape)
# Out:
# (7500, 128, 128, 3)
# (7500, 2)
# (1200, 128, 128, 3)

# %%
# shuffle training instances
idx = np.random.randint(train_images_ss.shape[0], size=train_images_ss.shape[0])
train_images_ss = train_images_ss[idx,:,:,:]
train_labels_ss = train_labels_ss[idx,:]
print("train_images shape:", train_images_ss.shape)
print("train_labels shape:", train_labels_ss.shape)
# Out:
# train_images shape: (7500, 128, 128, 3)
# train_labels shape: (7500, 2)

# %%
from skimage import transform
from skimage.transform import warp
from skimage.transform import ProjectiveTransform

img = deepcopy(train_images_ss[2])

original = np.array([[0,0],[0,128],[128,0],[128,128]])
warp_right = np.array([[0,32],[0,96],[128,0],[128,128]])
warp_left = np.array([[0,0],[0,128],[128,32],[128,96]])
warp_top = np.array([[32,0],[0,128],[96,0],[128,128]])
warp_bottom = np.array([[0,0],[32,128],[128,0],[96,128]])
transform_right = ProjectiveTransform()
transform_right.estimate(original, warp_right)
transform_left = ProjectiveTransform()
transform_left.estimate(original, warp_left)
transform_top = ProjectiveTransform()
transform_top.estimate(original, warp_top)
transform_bottom = ProjectiveTransform()
transform_bottom.estimate(original, warp_bottom)

warped_img_right = warp(img, transform_right)
warped_img_left = warp(img, transform_left)
warped_img_top = warp(img, transform_top)
warped_img_bottom = warp(img, transform_bottom)


plt.subplots(figsize=(15, 15)) 
plt.subplot(5,1,1)
plt.imshow(img)
plt.title('original')
plt.axis('off')
plt.subplot(5,1,2)
plt.imshow(warped_img_right)
plt.title('warped right')
plt.axis('off')
plt.subplot(5,1,3)
plt.imshow(warped_img_left)
plt.title('warped left')
plt.axis('off')
plt.subplot(5,1,4)
plt.imshow(warped_img_top)
plt.title('warped top')
plt.axis('off')
plt.subplot(5,1,5)
plt.imshow(warped_img_bottom)
plt.title('warped bottom')
plt.axis('off')
plt.show()

# %%
from skimage import transform
from skimage.transform import warp
from skimage.transform import ProjectiveTransform

original = np.array([[0,0],[0,128],[128,0],[128,128]])
warp_right = np.array([[0,32],[0,96],[128,0],[128,128]])
warp_left = np.array([[0,0],[0,128],[128,32],[128,96]])
warp_top = np.array([[32,0],[0,128],[96,0],[128,128]])
warp_bottom = np.array([[0,0],[32,128],[128,0],[96,128]])
transform_right = ProjectiveTransform()
transform_right.estimate(original, warp_right)
transform_left = ProjectiveTransform()
transform_left.estimate(original, warp_left)
transform_top = ProjectiveTransform()
transform_top.estimate(original, warp_top)
transform_bottom = ProjectiveTransform()
transform_bottom.estimate(original, warp_bottom)

train_images_warp=np.zeros((train_images_ss.shape[0]*5, 128, 128, 3))

train_label_warp=np.zeros((train_labels_ss.shape[0] * 5,1) )
#0: no warping, 1 warp right, 2 warp left, 3 warp top, 4 warp bottom
count = 0
for i in range (train_images_ss.shape[0]):
    
    img= train_images_ss[i,:,:,:] # Original
    
    img1 = img
    lab1 = 0
    train_images_warp[count,:,:,:] = img1
    train_label_warp[i,0]=lab1
    
    img2 = img
    lab2 = 1
    train_images_warp[count+1,:,:,:] = warp(img2, transform_right)
    train_label_warp[i,0]=lab2
    
    img3 = img
    lab3 = 2
    train_images_warp[count+2,:,:,:] = warp(img3, transform_left)
    train_label_warp[i,0]=lab3
    
    img4 = img
    lab4 = 3
    train_images_warp[count+3,:,:,:] = warp(img4, transform_top)
    train_label_warp[i,0]=lab4
    
    img5 = img
    lab5 = 4
    train_images_warp[count+4,:,:,:] = warp(img5, transform_bottom)
    train_label_warp[i,0]=lab5
    
    
    
#     if np.mod(i,5)==0:
#     warped_img = img 
#     warped_label = 0
# #     elif np.mod(i,5)==1:
#     warped_img = warp(img, transform_right)
#     warped_label=1
#   #  elif np.mod(i,5)==2:
#     warped_img = warp(img, transform_left)
#     warped_label=2
#   #  elif np.mod(i,5)==3:
#     warped_img = warp(img, transform_top)
#     warped_label=3
#   #  else:
#     warped_img = warp(img, transform_bottom)
#     warped_label=4
        
#     train_images_warp[i,:,:,:] = warped_img
#     train_label_warp[i,0]=warped_label
    count += 4


print(train_images_warp.shape)
print(train_label_warp.shape)

# %%
print(train_images_warp[:10])
print(train_label_warp[:10])

# %%
base_model = keras.Sequential(
    [
        layers.Input((128, 128, 3)),
        layers.Conv2D(16, (3, 3), activation='relu'), # 126
        layers.Conv2D(16, (3, 3), activation='relu'), # 124
        layers.MaxPooling2D((3, 3),padding='same'), # 42
   
        layers.Conv2D(32, (3, 3), activation='relu'), # 40
        layers.Conv2D(32, (3, 3), activation='relu'), # 38
        layers.MaxPooling2D((3, 3),padding='same'), # 13
 
        layers.Conv2D(64, (3, 3), activation='relu'), # 11
        layers.Conv2D(64, (3, 3), activation='relu'), # 9
        layers.MaxPooling2D((3, 3),padding='same'), # 3
        layers.MaxPooling2D((2, 2),padding='same'), # 2
        
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dense(5, activation='softmax')
    ]
)

base_model.summary()

#compile model
loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False)

base_model.compile(optimizer='adam', loss=[loss], metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 124, 124, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 42, 42, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 40, 40, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 38, 38, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 139,157
# Trainable params: 139,157
# Non-trainable params: 0
# _________________________________________________________________

# %%
warp_history=base_model.fit(train_images_warp,train_label_warp, verbose = 1,validation_split = 0.2,
                           epochs=20, batch_size=100)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 6s 26ms/step - loss: 1.3908 - accuracy: 0.3945 - val_loss: 1.0923 - val_accuracy: 0.6013
# Epoch 2/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.8423 - accuracy: 0.6882 - val_loss: 0.5718 - val_accuracy: 0.7827
# Epoch 3/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.3801 - accuracy: 0.8673 - val_loss: 0.1965 - val_accuracy: 0.9300
# Epoch 4/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2657 - accuracy: 0.9117 - val_loss: 0.1975 - val_accuracy: 0.9287
# Epoch 5/20
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1477 - accuracy: 0.9478 - val_loss: 0.0990 - val_accuracy: 0.9673
# Epoch 6/20
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1153 - accuracy: 0.9602 - val_loss: 0.0898 - val_accuracy: 0.9707
# Epoch 7/20
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0720 - accuracy: 0.9747 - val_loss: 0.1052 - val_accuracy: 0.9693
# Epoch 8/20
# 60/60 [==============================] - 1s 21ms/step - loss: 0.2257 - accuracy: 0.9270 - val_loss: 0.0862 - val_accuracy: 0.9733
# Epoch 9/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0624 - accuracy: 0.9800 - val_loss: 0.0523 - val_accuracy: 0.9833
# Epoch 10/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0719 - accuracy: 0.9763 - val_loss: 0.0897 - val_accuracy: 0.9693
# Epoch 11/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0574 - accuracy: 0.9803 - val_loss: 0.0652 - val_accuracy: 0.9793
# Epoch 12/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0446 - accuracy: 0.9865 - val_loss: 0.0453 - val_accuracy: 0.9853
# Epoch 13/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0659 - accuracy: 0.9738 - val_loss: 0.0916 - val_accuracy: 0.9633
# Epoch 14/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0570 - accuracy: 0.9803 - val_loss: 0.0464 - val_accuracy: 0.9880
# Epoch 15/20
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0446 - accuracy: 0.9845 - val_loss: 0.0442 - val_accuracy: 0.9853
# Epoch 16/20
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0580 - accuracy: 0.9795 - val_loss: 0.0539 - val_accuracy: 0.9840
# Epoch 17/20
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0405 - accuracy: 0.9865 - val_loss: 0.0338 - val_accuracy: 0.9927
# Epoch 18/20
# 60/60 [==============================] - 1s 21ms/step - loss: 0.0331 - accuracy: 0.9897 - val_loss: 0.0821 - val_accuracy: 0.9713
# Epoch 19/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0371 - accuracy: 0.9878 - val_loss: 0.0382 - val_accuracy: 0.9887
# Epoch 20/20
# 60/60 [==============================] - 1s 20ms/step - loss: 0.0278 - accuracy: 0.9898 - val_loss: 0.0364 - val_accuracy: 0.9900

# %%
# use the pre-trained (self-supervised learning) network to conduct feature extraction and classification
features_model=Model(base_model.inputs, base_model.layers[-3].output)
 
train_features = features_model.predict(train_images_ss)
print(train_features.shape)
# Out:
# (7500, 256)

# %%
#from tensorflow import keras
#from keras import layers
#import keras
# MLP for classification
pred_model = keras.Sequential(
    [
        layers.Input((256,)),
        layers.Dense(32, activation='relu'),
#         layers.Dense(128, activation='relu'),
        layers.Dense(32, activation='relu'),

        layers.Dense(1490, activation='softmax') #classification
        #layers.Dense(2, activation='linear') #regression
    ]
)

pred_model.summary()

#compile model
# parameters for classification
loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False)
pred_model.compile(optimizer='adam', loss=[loss], metrics=['accuracy'])
# parameters for regression
# pred_model.compile(optimizer='adam', loss="mae", metrics=['accuracy'])
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_37 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dense_38 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_39 (Dense)             (None, 1490)              49170
# =================================================================
# Total params: 58,450
# Trainable params: 58,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn import preprocessing

label_str=[str((x,y)) for x,y in train_labels_ss]
le = preprocessing.LabelEncoder()
le.fit(label_str)
int_labels= le.transform(label_str)



ss_history = pred_model.fit(train_features,int_labels, verbose = 1,validation_split = 0.2,epochs=300, batch_size=100)
# Out:
# Epoch 1/300
# 60/60 [==============================] - 0s 4ms/step - loss: 7.3026 - accuracy: 5.0000e-04 - val_loss: 7.2885 - val_accuracy: 6.6667e-04
# Epoch 2/300
# 60/60 [==============================] - 0s 3ms/step - loss: 7.1201 - accuracy: 0.0043 - val_loss: 7.2086 - val_accuracy: 0.0020
# Epoch 3/300
# 60/60 [==============================] - 0s 3ms/step - loss: 6.7607 - accuracy: 0.0100 - val_loss: 7.1941 - val_accuracy: 0.0033
# Epoch 4/300
# 60/60 [==============================] - 0s 3ms/step - loss: 6.4230 - accuracy: 0.0200 - val_loss: 7.1405 - val_accuracy: 0.0093
# Epoch 5/300
# 60/60 [==============================] - 0s 3ms/step - loss: 6.1063 - accuracy: 0.0315 - val_loss: 7.1530 - val_accuracy: 0.0167
# Epoch 6/300
# 60/60 [==============================] - 0s 3ms/step - loss: 5.8105 - accuracy: 0.0463 - val_loss: 7.2012 - val_accuracy: 0.0213
# Epoch 7/300
# 60/60 [==============================] - 0s 3ms/step - loss: 5.5543 - accuracy: 0.0733 - val_loss: 7.2317 - val_accuracy: 0.0340
# Epoch 8/300
# 60/60 [==============================] - 0s 3ms/step - loss: 5.3287 - accuracy: 0.0920 - val_loss: 7.3091 - val_accuracy: 0.0347
# Epoch 9/300
# 60/60 [==============================] - 0s 3ms/step - loss: 5.1317 - accuracy: 0.1135 - val_loss: 7.5219 - val_accuracy: 0.0427
# Epoch 10/300
# 60/60 [==============================] - 0s 3ms/step - loss: 4.9563 - accuracy: 0.1323 - val_loss: 7.5704 - val_accuracy: 0.0533
# Epoch 11/300
# 60/60 [==============================] - 0s 3ms/step - loss: 4.7853 - accuracy: 0.1517 - val_loss: 7.7628 - val_accuracy: 0.0627
# Epoch 12/300
# 60/60 [==============================] - 0s 2ms/step - loss: 4.6337 - accuracy: 0.1708 - val_loss: 7.8656 - val_accuracy: 0.0720
# Epoch 13/300
# 60/60 [==============================] - 0s 3ms/step - loss: 4.4996 - accuracy: 0.1930 - val_loss: 8.0757 - val_accuracy: 0.0840
# Epoch 14/300
# 60/60 [==============================] - 0s 3ms/step - loss: 4.3760 - accuracy: 0.2115 - val_loss: 8.2232 - val_accuracy: 0.0887
# Epoch 15/300
# 60/60 [==============================] - 0s 3ms/step - loss: 4.2655 - accuracy: 0.2233 - val_loss: 8.2954 - val_accuracy: 0.0960
# Epoch 16/300
# 60/60 [==============================] - 0s 3ms/step - loss: 4.1479 - accuracy: 0.2373 - val_loss: 8.5231 - val_accuracy: 0.1053
# Epoch 17/300
# 60/60 [==============================] - 0s 3ms/step - loss: 4.0413 - accuracy: 0.2575 - val_loss: 8.6943 - val_accuracy: 0.1080
# Epoch 18/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.9513 - accuracy: 0.2727 - val_loss: 8.8053 - val_accuracy: 0.1213
# Epoch 19/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.8584 - accuracy: 0.2860 - val_loss: 9.0552 - val_accuracy: 0.1300
# Epoch 20/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.7667 - accuracy: 0.3023 - val_loss: 9.0922 - val_accuracy: 0.1260
# Epoch 21/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.6834 - accuracy: 0.3112 - val_loss: 9.3019 - val_accuracy: 0.1400
# Epoch 22/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.5921 - accuracy: 0.3322 - val_loss: 9.5629 - val_accuracy: 0.1527
# Epoch 23/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.5093 - accuracy: 0.3402 - val_loss: 9.6141 - val_accuracy: 0.1627
# Epoch 24/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.4385 - accuracy: 0.3560 - val_loss: 9.8363 - val_accuracy: 0.1627
# Epoch 25/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.3613 - accuracy: 0.3640 - val_loss: 10.0586 - val_accuracy: 0.1687
# Epoch 26/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.2988 - accuracy: 0.3777 - val_loss: 10.1556 - val_accuracy: 0.1767
# Epoch 27/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.2180 - accuracy: 0.3882 - val_loss: 10.3121 - val_accuracy: 0.1827
# Epoch 28/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.1656 - accuracy: 0.3948 - val_loss: 10.5363 - val_accuracy: 0.1893
# Epoch 29/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.0975 - accuracy: 0.4092 - val_loss: 10.7256 - val_accuracy: 0.1853
# Epoch 30/300
# 60/60 [==============================] - 0s 3ms/step - loss: 3.0290 - accuracy: 0.4192 - val_loss: 10.9400 - val_accuracy: 0.1967
# Epoch 31/300
# 60/60 [==============================] - 0s 2ms/step - loss: 2.9805 - accuracy: 0.4238 - val_loss: 11.0244 - val_accuracy: 0.1993
# Epoch 32/300
# 60/60 [==============================] - 0s 2ms/step - loss: 2.9124 - accuracy: 0.4433 - val_loss: 11.3364 - val_accuracy: 0.2033
# Epoch 33/300
# 60/60 [==============================] - 0s 2ms/step - loss: 2.8585 - accuracy: 0.4468 - val_loss: 11.4213 - val_accuracy: 0.2127
# Epoch 34/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.8004 - accuracy: 0.4563 - val_loss: 11.6447 - val_accuracy: 0.2133
# Epoch 35/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.7578 - accuracy: 0.4642 - val_loss: 11.7664 - val_accuracy: 0.2187
# Epoch 36/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.6986 - accuracy: 0.4717 - val_loss: 11.9438 - val_accuracy: 0.2253
# Epoch 37/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.6440 - accuracy: 0.4790 - val_loss: 12.2686 - val_accuracy: 0.2273
# Epoch 38/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.5956 - accuracy: 0.4865 - val_loss: 12.3543 - val_accuracy: 0.2367
# Epoch 39/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.5518 - accuracy: 0.4953 - val_loss: 12.6039 - val_accuracy: 0.2453
# Epoch 40/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.5057 - accuracy: 0.5058 - val_loss: 12.6815 - val_accuracy: 0.2413
# Epoch 41/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.4583 - accuracy: 0.5133 - val_loss: 12.9179 - val_accuracy: 0.2473
# Epoch 42/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.4154 - accuracy: 0.5193 - val_loss: 13.0531 - val_accuracy: 0.2540
# Epoch 43/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.3827 - accuracy: 0.5235 - val_loss: 13.3450 - val_accuracy: 0.2680
# Epoch 44/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.3374 - accuracy: 0.5332 - val_loss: 13.4153 - val_accuracy: 0.2600
# Epoch 45/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.3027 - accuracy: 0.5365 - val_loss: 13.5931 - val_accuracy: 0.2740
# Epoch 46/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.2548 - accuracy: 0.5482 - val_loss: 13.7440 - val_accuracy: 0.2647
# Epoch 47/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.2265 - accuracy: 0.5537 - val_loss: 13.9181 - val_accuracy: 0.2780
# Epoch 48/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.1953 - accuracy: 0.5617 - val_loss: 14.3745 - val_accuracy: 0.2827
# Epoch 49/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.1488 - accuracy: 0.5683 - val_loss: 14.3608 - val_accuracy: 0.2920
# Epoch 50/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.1130 - accuracy: 0.5753 - val_loss: 14.5650 - val_accuracy: 0.2833
# Epoch 51/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.0784 - accuracy: 0.5815 - val_loss: 14.7727 - val_accuracy: 0.2947
# Epoch 52/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.0447 - accuracy: 0.5888 - val_loss: 14.9843 - val_accuracy: 0.2880
# Epoch 53/300
# 60/60 [==============================] - 0s 3ms/step - loss: 2.0238 - accuracy: 0.5880 - val_loss: 15.1083 - val_accuracy: 0.3047
# Epoch 54/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.9874 - accuracy: 0.5990 - val_loss: 15.2269 - val_accuracy: 0.3140
# Epoch 55/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.9484 - accuracy: 0.6047 - val_loss: 15.5255 - val_accuracy: 0.3060
# Epoch 56/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.9321 - accuracy: 0.6057 - val_loss: 15.5963 - val_accuracy: 0.3100
# Epoch 57/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.8884 - accuracy: 0.6150 - val_loss: 15.9001 - val_accuracy: 0.3147
# Epoch 58/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.8631 - accuracy: 0.6203 - val_loss: 16.0663 - val_accuracy: 0.3213
# Epoch 59/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.8350 - accuracy: 0.6225 - val_loss: 16.1886 - val_accuracy: 0.3227
# Epoch 60/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.8140 - accuracy: 0.6303 - val_loss: 16.4149 - val_accuracy: 0.3313
# Epoch 61/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.7875 - accuracy: 0.6310 - val_loss: 16.6596 - val_accuracy: 0.3300
# Epoch 62/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.7563 - accuracy: 0.6402 - val_loss: 16.8163 - val_accuracy: 0.3313
# Epoch 63/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.7281 - accuracy: 0.6443 - val_loss: 16.8987 - val_accuracy: 0.3373
# Epoch 64/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.7066 - accuracy: 0.6543 - val_loss: 17.1354 - val_accuracy: 0.3340
# Epoch 65/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.6811 - accuracy: 0.6588 - val_loss: 17.4034 - val_accuracy: 0.3413
# Epoch 66/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.6596 - accuracy: 0.6563 - val_loss: 17.2739 - val_accuracy: 0.3473
# Epoch 67/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.6367 - accuracy: 0.6585 - val_loss: 17.7706 - val_accuracy: 0.3593
# Epoch 68/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.6018 - accuracy: 0.6713 - val_loss: 17.9702 - val_accuracy: 0.3627
# Epoch 69/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.5824 - accuracy: 0.6728 - val_loss: 18.1589 - val_accuracy: 0.3600
# Epoch 70/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.5615 - accuracy: 0.6777 - val_loss: 18.3604 - val_accuracy: 0.3693
# Epoch 71/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.5353 - accuracy: 0.6838 - val_loss: 18.5567 - val_accuracy: 0.3620
# Epoch 72/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.5195 - accuracy: 0.6907 - val_loss: 18.6802 - val_accuracy: 0.3580
# Epoch 73/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.4973 - accuracy: 0.6948 - val_loss: 19.0349 - val_accuracy: 0.3587
# Epoch 74/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.4896 - accuracy: 0.6967 - val_loss: 19.1486 - val_accuracy: 0.3720
# Epoch 75/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.4591 - accuracy: 0.6990 - val_loss: 19.1718 - val_accuracy: 0.3800
# Epoch 76/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.4421 - accuracy: 0.7015 - val_loss: 19.3441 - val_accuracy: 0.3833
# Epoch 77/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.4180 - accuracy: 0.7128 - val_loss: 19.5648 - val_accuracy: 0.3720
# Epoch 78/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.4019 - accuracy: 0.7100 - val_loss: 19.8574 - val_accuracy: 0.3800
# Epoch 79/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.3920 - accuracy: 0.7087 - val_loss: 19.8742 - val_accuracy: 0.3807
# Epoch 80/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.3729 - accuracy: 0.7175 - val_loss: 20.0647 - val_accuracy: 0.3820
# Epoch 81/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.3440 - accuracy: 0.7303 - val_loss: 20.4063 - val_accuracy: 0.3893
# Epoch 82/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.3256 - accuracy: 0.7307 - val_loss: 20.6218 - val_accuracy: 0.3827
# Epoch 83/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.3172 - accuracy: 0.7245 - val_loss: 20.6058 - val_accuracy: 0.3893
# Epoch 84/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2979 - accuracy: 0.7327 - val_loss: 21.0033 - val_accuracy: 0.3847
# Epoch 85/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2889 - accuracy: 0.7342 - val_loss: 21.0126 - val_accuracy: 0.3953
# Epoch 86/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2678 - accuracy: 0.7402 - val_loss: 21.4337 - val_accuracy: 0.3940
# Epoch 87/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2498 - accuracy: 0.7397 - val_loss: 21.5125 - val_accuracy: 0.3993
# Epoch 88/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2311 - accuracy: 0.7435 - val_loss: 21.6720 - val_accuracy: 0.4020
# Epoch 89/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.2138 - accuracy: 0.7505 - val_loss: 21.7320 - val_accuracy: 0.4080
# Epoch 90/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.1992 - accuracy: 0.7512 - val_loss: 22.0050 - val_accuracy: 0.4040
# Epoch 91/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.1839 - accuracy: 0.7552 - val_loss: 22.2998 - val_accuracy: 0.4053
# Epoch 92/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.1673 - accuracy: 0.7562 - val_loss: 22.3331 - val_accuracy: 0.4027
# Epoch 93/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.1645 - accuracy: 0.7553 - val_loss: 22.6953 - val_accuracy: 0.4073
# Epoch 94/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.1648 - accuracy: 0.7595 - val_loss: 22.6273 - val_accuracy: 0.4040
# Epoch 95/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.1296 - accuracy: 0.7683 - val_loss: 22.9212 - val_accuracy: 0.4173
# Epoch 96/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.1129 - accuracy: 0.7737 - val_loss: 23.2088 - val_accuracy: 0.4167
# Epoch 97/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0964 - accuracy: 0.7737 - val_loss: 23.2849 - val_accuracy: 0.4187
# Epoch 98/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0931 - accuracy: 0.7785 - val_loss: 23.4070 - val_accuracy: 0.4267
# Epoch 99/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0810 - accuracy: 0.7757 - val_loss: 23.7165 - val_accuracy: 0.4220
# Epoch 100/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0659 - accuracy: 0.7805 - val_loss: 24.0092 - val_accuracy: 0.4153
# Epoch 101/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0619 - accuracy: 0.7813 - val_loss: 23.9411 - val_accuracy: 0.4147
# Epoch 102/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0456 - accuracy: 0.7833 - val_loss: 24.2467 - val_accuracy: 0.4273
# Epoch 103/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0365 - accuracy: 0.7848 - val_loss: 24.2825 - val_accuracy: 0.4253
# Epoch 104/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0138 - accuracy: 0.7848 - val_loss: 24.4965 - val_accuracy: 0.4300
# Epoch 105/300
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0022 - accuracy: 0.7897 - val_loss: 24.6574 - val_accuracy: 0.4333
# Epoch 106/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9934 - accuracy: 0.7952 - val_loss: 25.0324 - val_accuracy: 0.4220
# Epoch 107/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9827 - accuracy: 0.7947 - val_loss: 25.0258 - val_accuracy: 0.4300
# Epoch 108/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9682 - accuracy: 0.8012 - val_loss: 25.4793 - val_accuracy: 0.4220
# Epoch 109/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9749 - accuracy: 0.7955 - val_loss: 25.6427 - val_accuracy: 0.4207
# Epoch 110/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9653 - accuracy: 0.8002 - val_loss: 25.6993 - val_accuracy: 0.4347
# Epoch 111/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9386 - accuracy: 0.8065 - val_loss: 25.8339 - val_accuracy: 0.4387
# Epoch 112/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9211 - accuracy: 0.8123 - val_loss: 26.1835 - val_accuracy: 0.4493
# Epoch 113/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9211 - accuracy: 0.8083 - val_loss: 26.1951 - val_accuracy: 0.4327
# Epoch 114/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9011 - accuracy: 0.8190 - val_loss: 26.3923 - val_accuracy: 0.4407
# Epoch 115/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8798 - accuracy: 0.8193 - val_loss: 26.6085 - val_accuracy: 0.4447
# Epoch 116/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8806 - accuracy: 0.8185 - val_loss: 26.8804 - val_accuracy: 0.4373
# Epoch 117/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8779 - accuracy: 0.8155 - val_loss: 26.9980 - val_accuracy: 0.4367
# Epoch 118/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8750 - accuracy: 0.8198 - val_loss: 27.0942 - val_accuracy: 0.4407
# Epoch 119/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8551 - accuracy: 0.8250 - val_loss: 27.2462 - val_accuracy: 0.4440
# Epoch 120/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8480 - accuracy: 0.8215 - val_loss: 27.3776 - val_accuracy: 0.4527
# Epoch 121/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8288 - accuracy: 0.8293 - val_loss: 27.5710 - val_accuracy: 0.4440
# Epoch 122/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8276 - accuracy: 0.8290 - val_loss: 27.8792 - val_accuracy: 0.4460
# Epoch 123/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8195 - accuracy: 0.8278 - val_loss: 28.3771 - val_accuracy: 0.4507
# Epoch 124/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8138 - accuracy: 0.8278 - val_loss: 28.3321 - val_accuracy: 0.4540
# Epoch 125/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8019 - accuracy: 0.8367 - val_loss: 28.4398 - val_accuracy: 0.4513
# Epoch 126/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8010 - accuracy: 0.8332 - val_loss: 28.7673 - val_accuracy: 0.4507
# Epoch 127/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7866 - accuracy: 0.8362 - val_loss: 28.5913 - val_accuracy: 0.4600
# Epoch 128/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7764 - accuracy: 0.8357 - val_loss: 28.9550 - val_accuracy: 0.4560
# Epoch 129/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7586 - accuracy: 0.8445 - val_loss: 29.1408 - val_accuracy: 0.4607
# Epoch 130/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7590 - accuracy: 0.8443 - val_loss: 29.2509 - val_accuracy: 0.4567
# Epoch 131/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7495 - accuracy: 0.8427 - val_loss: 29.4774 - val_accuracy: 0.4527
# Epoch 132/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7359 - accuracy: 0.8512 - val_loss: 29.4341 - val_accuracy: 0.4640
# Epoch 133/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7343 - accuracy: 0.8483 - val_loss: 29.8958 - val_accuracy: 0.4567
# Epoch 134/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7256 - accuracy: 0.8492 - val_loss: 30.1833 - val_accuracy: 0.4613
# Epoch 135/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7161 - accuracy: 0.8530 - val_loss: 30.0624 - val_accuracy: 0.4560
# Epoch 136/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7110 - accuracy: 0.8535 - val_loss: 30.2945 - val_accuracy: 0.4700
# Epoch 137/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.7003 - accuracy: 0.8578 - val_loss: 30.5084 - val_accuracy: 0.4640
# Epoch 138/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6956 - accuracy: 0.8573 - val_loss: 30.7183 - val_accuracy: 0.4620
# Epoch 139/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.8560 - val_loss: 30.7224 - val_accuracy: 0.4733
# Epoch 140/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6727 - accuracy: 0.8632 - val_loss: 31.2715 - val_accuracy: 0.4707
# Epoch 141/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6730 - accuracy: 0.8625 - val_loss: 31.0749 - val_accuracy: 0.4673
# Epoch 142/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6639 - accuracy: 0.8647 - val_loss: 31.2368 - val_accuracy: 0.4680
# Epoch 143/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6527 - accuracy: 0.8678 - val_loss: 31.6995 - val_accuracy: 0.4707
# Epoch 144/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6335 - accuracy: 0.8695 - val_loss: 31.7330 - val_accuracy: 0.4747
# Epoch 145/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6346 - accuracy: 0.8720 - val_loss: 31.8511 - val_accuracy: 0.4693
# Epoch 146/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6580 - accuracy: 0.8592 - val_loss: 31.9751 - val_accuracy: 0.4627
# Epoch 147/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6396 - accuracy: 0.8665 - val_loss: 32.1585 - val_accuracy: 0.4700
# Epoch 148/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6348 - accuracy: 0.8663 - val_loss: 32.4270 - val_accuracy: 0.4720
# Epoch 149/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.8740 - val_loss: 32.7918 - val_accuracy: 0.4700
# Epoch 150/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6104 - accuracy: 0.8737 - val_loss: 32.8357 - val_accuracy: 0.4753
# Epoch 151/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6019 - accuracy: 0.8752 - val_loss: 33.0729 - val_accuracy: 0.4733
# Epoch 152/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5966 - accuracy: 0.8768 - val_loss: 33.0813 - val_accuracy: 0.4807
# Epoch 153/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5915 - accuracy: 0.8800 - val_loss: 33.1576 - val_accuracy: 0.4747
# Epoch 154/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5940 - accuracy: 0.8760 - val_loss: 33.6682 - val_accuracy: 0.4647
# Epoch 155/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5952 - accuracy: 0.8763 - val_loss: 33.8022 - val_accuracy: 0.4813
# Epoch 156/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5873 - accuracy: 0.8753 - val_loss: 33.6297 - val_accuracy: 0.4760
# Epoch 157/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.8788 - val_loss: 33.9661 - val_accuracy: 0.4760
# Epoch 158/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5727 - accuracy: 0.8803 - val_loss: 34.0248 - val_accuracy: 0.4873
# Epoch 159/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.8867 - val_loss: 34.4495 - val_accuracy: 0.4787
# Epoch 160/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5399 - accuracy: 0.8922 - val_loss: 34.5225 - val_accuracy: 0.4913
# Epoch 161/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5251 - accuracy: 0.8935 - val_loss: 34.8156 - val_accuracy: 0.4853
# Epoch 162/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.8958 - val_loss: 35.0088 - val_accuracy: 0.4867
# Epoch 163/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5307 - accuracy: 0.8892 - val_loss: 34.9364 - val_accuracy: 0.4880
# Epoch 164/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5131 - accuracy: 0.8962 - val_loss: 35.4431 - val_accuracy: 0.4800
# Epoch 165/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5144 - accuracy: 0.8948 - val_loss: 35.2577 - val_accuracy: 0.4860
# Epoch 166/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5114 - accuracy: 0.8955 - val_loss: 35.8600 - val_accuracy: 0.4813
# Epoch 167/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5112 - accuracy: 0.8897 - val_loss: 35.8442 - val_accuracy: 0.4793
# Epoch 168/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4969 - accuracy: 0.8965 - val_loss: 36.0179 - val_accuracy: 0.4833
# Epoch 169/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4903 - accuracy: 0.9007 - val_loss: 36.0001 - val_accuracy: 0.4933
# Epoch 170/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4803 - accuracy: 0.9037 - val_loss: 36.3397 - val_accuracy: 0.4933
# Epoch 171/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4821 - accuracy: 0.9053 - val_loss: 36.4903 - val_accuracy: 0.4900
# Epoch 172/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4888 - accuracy: 0.9062 - val_loss: 36.6758 - val_accuracy: 0.4893
# Epoch 173/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4892 - accuracy: 0.8975 - val_loss: 36.8625 - val_accuracy: 0.4880
# Epoch 174/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4769 - accuracy: 0.9025 - val_loss: 37.1135 - val_accuracy: 0.4867
# Epoch 175/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4740 - accuracy: 0.9008 - val_loss: 37.3610 - val_accuracy: 0.4893
# Epoch 176/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4700 - accuracy: 0.9005 - val_loss: 37.2171 - val_accuracy: 0.4967
# Epoch 177/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4604 - accuracy: 0.9073 - val_loss: 37.3581 - val_accuracy: 0.4933
# Epoch 178/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4418 - accuracy: 0.9082 - val_loss: 37.4941 - val_accuracy: 0.4933
# Epoch 179/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4409 - accuracy: 0.9087 - val_loss: 37.7908 - val_accuracy: 0.4980
# Epoch 180/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4427 - accuracy: 0.9077 - val_loss: 37.9329 - val_accuracy: 0.4953
# Epoch 181/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4469 - accuracy: 0.9065 - val_loss: 37.8825 - val_accuracy: 0.4947
# Epoch 182/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4565 - accuracy: 0.9015 - val_loss: 38.1849 - val_accuracy: 0.4947
# Epoch 183/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.9035 - val_loss: 38.1167 - val_accuracy: 0.4973
# Epoch 184/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4331 - accuracy: 0.9097 - val_loss: 38.7929 - val_accuracy: 0.4993
# Epoch 185/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4251 - accuracy: 0.9128 - val_loss: 38.8703 - val_accuracy: 0.5007
# Epoch 186/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4271 - accuracy: 0.9087 - val_loss: 39.2673 - val_accuracy: 0.4947
# Epoch 187/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4123 - accuracy: 0.9145 - val_loss: 39.3412 - val_accuracy: 0.4893
# Epoch 188/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4169 - accuracy: 0.9127 - val_loss: 39.3796 - val_accuracy: 0.5007
# Epoch 189/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.9095 - val_loss: 39.3958 - val_accuracy: 0.4960
# Epoch 190/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.9155 - val_loss: 39.6313 - val_accuracy: 0.4953
# Epoch 191/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4198 - accuracy: 0.9090 - val_loss: 39.8067 - val_accuracy: 0.4980
# Epoch 192/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3996 - accuracy: 0.9158 - val_loss: 40.2145 - val_accuracy: 0.4987
# Epoch 193/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3897 - accuracy: 0.9245 - val_loss: 40.1375 - val_accuracy: 0.5027
# Epoch 194/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.9228 - val_loss: 40.6078 - val_accuracy: 0.4973
# Epoch 195/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3997 - accuracy: 0.9165 - val_loss: 40.3175 - val_accuracy: 0.5007
# Epoch 196/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3807 - accuracy: 0.9188 - val_loss: 40.7467 - val_accuracy: 0.4993
# Epoch 197/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3677 - accuracy: 0.9260 - val_loss: 40.8321 - val_accuracy: 0.5060
# Epoch 198/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3585 - accuracy: 0.9313 - val_loss: 40.9196 - val_accuracy: 0.5007
# Epoch 199/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3451 - accuracy: 0.9310 - val_loss: 41.1316 - val_accuracy: 0.5053
# Epoch 200/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3506 - accuracy: 0.9278 - val_loss: 41.3711 - val_accuracy: 0.5020
# Epoch 201/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3659 - accuracy: 0.9287 - val_loss: 41.5830 - val_accuracy: 0.5007
# Epoch 202/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3486 - accuracy: 0.9327 - val_loss: 41.3275 - val_accuracy: 0.5080
# Epoch 203/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3548 - accuracy: 0.9250 - val_loss: 41.7987 - val_accuracy: 0.5080
# Epoch 204/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3536 - accuracy: 0.9277 - val_loss: 42.2330 - val_accuracy: 0.5080
# Epoch 205/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3334 - accuracy: 0.9355 - val_loss: 42.0265 - val_accuracy: 0.5087
# Epoch 206/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3344 - accuracy: 0.9327 - val_loss: 42.4699 - val_accuracy: 0.5047
# Epoch 207/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3503 - accuracy: 0.9258 - val_loss: 42.3693 - val_accuracy: 0.5073
# Epoch 208/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3436 - accuracy: 0.9262 - val_loss: 42.6771 - val_accuracy: 0.5047
# Epoch 209/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3342 - accuracy: 0.9337 - val_loss: 42.7983 - val_accuracy: 0.5087
# Epoch 210/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3371 - accuracy: 0.9300 - val_loss: 42.7388 - val_accuracy: 0.5087
# Epoch 211/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3891 - accuracy: 0.9103 - val_loss: 43.0361 - val_accuracy: 0.4953
# Epoch 212/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3570 - accuracy: 0.9207 - val_loss: 43.4505 - val_accuracy: 0.5013
# Epoch 213/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3342 - accuracy: 0.9292 - val_loss: 43.1772 - val_accuracy: 0.5047
# Epoch 214/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3293 - accuracy: 0.9302 - val_loss: 43.3054 - val_accuracy: 0.5073
# Epoch 215/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3076 - accuracy: 0.9385 - val_loss: 43.6285 - val_accuracy: 0.5120
# Epoch 216/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2917 - accuracy: 0.9432 - val_loss: 43.6427 - val_accuracy: 0.5113
# Epoch 217/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2874 - accuracy: 0.9450 - val_loss: 44.1292 - val_accuracy: 0.5120
# Epoch 218/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2840 - accuracy: 0.9442 - val_loss: 44.0587 - val_accuracy: 0.5147
# Epoch 219/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2696 - accuracy: 0.9482 - val_loss: 44.2963 - val_accuracy: 0.5113
# Epoch 220/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2754 - accuracy: 0.9445 - val_loss: 44.5779 - val_accuracy: 0.5107
# Epoch 221/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2801 - accuracy: 0.9420 - val_loss: 44.4822 - val_accuracy: 0.5107
# Epoch 222/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2833 - accuracy: 0.9452 - val_loss: 44.7156 - val_accuracy: 0.5107
# Epoch 223/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2815 - accuracy: 0.9423 - val_loss: 44.6794 - val_accuracy: 0.5140
# Epoch 224/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2765 - accuracy: 0.9440 - val_loss: 45.2317 - val_accuracy: 0.5080
# Epoch 225/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.9453 - val_loss: 45.4041 - val_accuracy: 0.5133
# Epoch 226/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2728 - accuracy: 0.9470 - val_loss: 45.2773 - val_accuracy: 0.5087
# Epoch 227/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2784 - accuracy: 0.9425 - val_loss: 45.5312 - val_accuracy: 0.5120
# Epoch 228/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2865 - accuracy: 0.9413 - val_loss: 45.6315 - val_accuracy: 0.5113
# Epoch 229/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2979 - accuracy: 0.9397 - val_loss: 45.8619 - val_accuracy: 0.5093
# Epoch 230/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.9287 - val_loss: 46.0538 - val_accuracy: 0.5007
# Epoch 231/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3138 - accuracy: 0.9302 - val_loss: 46.4428 - val_accuracy: 0.5013
# Epoch 232/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3404 - accuracy: 0.9187 - val_loss: 46.2662 - val_accuracy: 0.5020
# Epoch 233/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3345 - accuracy: 0.9200 - val_loss: 46.6099 - val_accuracy: 0.4947
# Epoch 234/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3213 - accuracy: 0.9245 - val_loss: 46.7627 - val_accuracy: 0.5000
# Epoch 235/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3031 - accuracy: 0.9313 - val_loss: 47.0238 - val_accuracy: 0.5040
# Epoch 236/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2687 - accuracy: 0.9417 - val_loss: 46.9063 - val_accuracy: 0.5093
# Epoch 237/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2511 - accuracy: 0.9485 - val_loss: 46.6450 - val_accuracy: 0.5147
# Epoch 238/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9515 - val_loss: 46.9030 - val_accuracy: 0.5093
# Epoch 239/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2293 - accuracy: 0.9562 - val_loss: 47.2341 - val_accuracy: 0.5187
# Epoch 240/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2185 - accuracy: 0.9583 - val_loss: 47.6900 - val_accuracy: 0.5220
# Epoch 241/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9630 - val_loss: 47.5654 - val_accuracy: 0.5193
# Epoch 242/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2115 - accuracy: 0.9618 - val_loss: 47.8591 - val_accuracy: 0.5160
# Epoch 243/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2132 - accuracy: 0.9620 - val_loss: 47.9359 - val_accuracy: 0.5247
# Epoch 244/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2019 - accuracy: 0.9650 - val_loss: 48.1537 - val_accuracy: 0.5193
# Epoch 245/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2119 - accuracy: 0.9617 - val_loss: 48.3242 - val_accuracy: 0.5213
# Epoch 246/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2169 - accuracy: 0.9603 - val_loss: 48.3306 - val_accuracy: 0.5167
# Epoch 247/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2229 - accuracy: 0.9550 - val_loss: 48.4676 - val_accuracy: 0.5173
# Epoch 248/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2144 - accuracy: 0.9595 - val_loss: 48.6017 - val_accuracy: 0.5213
# Epoch 249/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2221 - accuracy: 0.9583 - val_loss: 48.6459 - val_accuracy: 0.5187
# Epoch 250/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9612 - val_loss: 48.9538 - val_accuracy: 0.5167
# Epoch 251/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2110 - accuracy: 0.9607 - val_loss: 48.9277 - val_accuracy: 0.5200
# Epoch 252/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2234 - accuracy: 0.9520 - val_loss: 49.2646 - val_accuracy: 0.5140
# Epoch 253/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2717 - accuracy: 0.9375 - val_loss: 49.7129 - val_accuracy: 0.5047
# Epoch 254/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2811 - accuracy: 0.9305 - val_loss: 49.7572 - val_accuracy: 0.5033
# Epoch 255/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2855 - accuracy: 0.9317 - val_loss: 49.6423 - val_accuracy: 0.5140
# Epoch 256/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2951 - accuracy: 0.9277 - val_loss: 49.5539 - val_accuracy: 0.5093
# Epoch 257/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.9342 - val_loss: 49.8314 - val_accuracy: 0.5133
# Epoch 258/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2580 - accuracy: 0.9383 - val_loss: 50.0603 - val_accuracy: 0.5133
# Epoch 259/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2527 - accuracy: 0.9380 - val_loss: 49.9507 - val_accuracy: 0.5113
# Epoch 260/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2333 - accuracy: 0.9508 - val_loss: 49.9782 - val_accuracy: 0.5180
# Epoch 261/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2041 - accuracy: 0.9577 - val_loss: 50.2638 - val_accuracy: 0.5247
# Epoch 262/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.9645 - val_loss: 50.5111 - val_accuracy: 0.5233
# Epoch 263/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.9640 - val_loss: 50.6590 - val_accuracy: 0.5193
# Epoch 264/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1825 - accuracy: 0.9653 - val_loss: 50.8325 - val_accuracy: 0.5213
# Epoch 265/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1748 - accuracy: 0.9685 - val_loss: 50.9269 - val_accuracy: 0.5247
# Epoch 266/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1646 - accuracy: 0.9705 - val_loss: 50.8655 - val_accuracy: 0.5253
# Epoch 267/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9732 - val_loss: 51.1656 - val_accuracy: 0.5233
# Epoch 268/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9748 - val_loss: 51.4230 - val_accuracy: 0.5280
# Epoch 269/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1522 - accuracy: 0.9753 - val_loss: 51.6791 - val_accuracy: 0.5273
# Epoch 270/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1552 - accuracy: 0.9747 - val_loss: 51.5611 - val_accuracy: 0.5293
# Epoch 271/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1518 - accuracy: 0.9753 - val_loss: 51.6160 - val_accuracy: 0.5293
# Epoch 272/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.9708 - val_loss: 51.5440 - val_accuracy: 0.5233
# Epoch 273/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1766 - accuracy: 0.9655 - val_loss: 52.1862 - val_accuracy: 0.5213
# Epoch 274/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1842 - accuracy: 0.9625 - val_loss: 52.2091 - val_accuracy: 0.5227
# Epoch 275/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1964 - accuracy: 0.9590 - val_loss: 52.1407 - val_accuracy: 0.5167
# Epoch 276/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9598 - val_loss: 52.3806 - val_accuracy: 0.5187
# Epoch 277/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2280 - accuracy: 0.9467 - val_loss: 52.4539 - val_accuracy: 0.5133
# Epoch 278/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2668 - accuracy: 0.9330 - val_loss: 52.9271 - val_accuracy: 0.4993
# Epoch 279/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3791 - accuracy: 0.8937 - val_loss: 52.8311 - val_accuracy: 0.5013
# Epoch 280/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3622 - accuracy: 0.9018 - val_loss: 52.6269 - val_accuracy: 0.4913
# Epoch 281/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3066 - accuracy: 0.9213 - val_loss: 52.9556 - val_accuracy: 0.5080
# Epoch 282/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2483 - accuracy: 0.9352 - val_loss: 53.2372 - val_accuracy: 0.5207
# Epoch 283/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1855 - accuracy: 0.9603 - val_loss: 53.0610 - val_accuracy: 0.5233
# Epoch 284/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1430 - accuracy: 0.9735 - val_loss: 53.1907 - val_accuracy: 0.5267
# Epoch 285/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1287 - accuracy: 0.9773 - val_loss: 53.3967 - val_accuracy: 0.5287
# Epoch 286/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 0.9825 - val_loss: 53.4584 - val_accuracy: 0.5320
# Epoch 287/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1108 - accuracy: 0.9827 - val_loss: 53.3005 - val_accuracy: 0.5300
# Epoch 288/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9852 - val_loss: 53.7859 - val_accuracy: 0.5293
# Epoch 289/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1095 - accuracy: 0.9833 - val_loss: 53.7361 - val_accuracy: 0.5307
# Epoch 290/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1067 - accuracy: 0.9857 - val_loss: 53.8370 - val_accuracy: 0.5313
# Epoch 291/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.9858 - val_loss: 54.2231 - val_accuracy: 0.5293
# Epoch 292/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1029 - accuracy: 0.9870 - val_loss: 54.2976 - val_accuracy: 0.5327
# Epoch 293/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1082 - accuracy: 0.9843 - val_loss: 54.2848 - val_accuracy: 0.5307
# Epoch 294/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1083 - accuracy: 0.9845 - val_loss: 54.3488 - val_accuracy: 0.5327
# Epoch 295/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.9852 - val_loss: 54.3600 - val_accuracy: 0.5300
# Epoch 296/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9810 - val_loss: 54.5377 - val_accuracy: 0.5287
# Epoch 297/300
# 60/60 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9823 - val_loss: 54.8733 - val_accuracy: 0.5300
# Epoch 298/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9847 - val_loss: 55.0187 - val_accuracy: 0.5280
# Epoch 299/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1209 - accuracy: 0.9813 - val_loss: 54.9261 - val_accuracy: 0.5307
# Epoch 300/300
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1431 - accuracy: 0.9723 - val_loss: 55.1834 - val_accuracy: 0.5220

# %%
plt.plot(ss_history.history['accuracy'], label='Train')
plt.plot(ss_history.history['val_accuracy'], label='Test')
plt.ylabel('Error')
plt.xlabel('Epoch')
plt.title('Training and testing accuracy')
plt.legend()
plt.show()

# %%
test_features = features_model.predict(test_images_ss)
print(test_features.shape)
# Out:
# (1200, 256)

# %%
test_predictions = pred_model.predict(test_features)
print(test_predictions.shape)
print(test_predictions)
# Out:
# (1200, 2)
# [[  37.714897  -42.234013]
#  [  51.75526    -4.724896]
#  [  41.75487   -20.885145]
#  ...
#  [-110.23699    21.98745 ]
#  [  22.674364  -64.911026]
#  [  14.764741  -49.388428]]

# %%
header = ['id', 'x', 'y']
with open(ROOTPATH + 'predictions_ss.csv', 'w', newline='') as predictions_ss:
    writer = csv.writer(predictions_ss)
    writer.writerow(header)
    for i in range(len(test_img_names)):
        img_name = test_img_names[i]
        x_val, y_val = test_predictions[i]
        data = [img_name, str(x_val), str(y_val)]
        writer.writerow(data)
    predictions_ss.close()
